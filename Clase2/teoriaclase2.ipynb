# %% [markdown]
# ## Clase 2- Fundamentos Python
# ## Variables y tipos de datos:

# %%
#---Esto es un comentario

nombre = " Javier Romero"
edad = 45
correo ="javier@gmail.com"
activo = True
promedio = 8.7

#--- Imprimir la información---

print(f"estudiante: {nombre}")
print(f"estudiante: {edad} → tipo{type(edad)}")
print(f"estudiante: {correo}")
print(f"estudiante: {activo}")
print(f"estudiante: {promedio}")
# Out:
# estudiante:  Javier Romero
# estudiante: 45 → tipo<class 'int'>
# estudiante: javier@gmail.com
# estudiante: True
# estudiante: 8.7

# %%
nombre = input("Ingresa nombre el estudiante: ")
edad= int(input("Ingresa edad: "))
print(f"Registrado{nombre} con una edad de : {edad}")
# Out:
# RegistradoPedro con una edad de : 36

# %% [markdown]
# str → string cadena de caracteres
# int → Enteros
# float → Float punto flotante, numeros con decimales
# bool → Booleano T/F

# %% [markdown]
# ## Listas y diccionarios
# > Listas:
# Colección ordenada, implementada como un array dinámico, su acceso lo tiene por indices

# %%
#Lista de estudiantes
estudiantes = ["Graciela", " Andrés", "Carolina"]
print(estudiantes[1])
print(estudiantes[0])
print(estudiantes[2])
print(estudiantes[-1])
print(estudiantes[-2])
print(len(estudiantes))
#Agregando un estudiante
estudiantes.append("Camila")
print(estudiantes)
# Out:
#  Andrés
# Graciela
# Carolina
# Carolina
#  Andrés
# 3
# ['Graciela', ' Andrés', 'Carolina', 'Camila']

# %% [markdown]
# # Diccionarios:
# Pares de clave - Valor

# %%
# Registro de estudiantes:

estudiante1 = {
    "nombre" : "Javier Romero",
    "edad" : 45,    
    "correo" : "javier@gmail.com",
    "activo" : True,
    "promedio" : 8.7
}

estudiante2= {
    "nombre" : "Pepito Romero",
    "edad" : 45,    
    "correo" : "pepito@gmail.com",
    "activo" : True,
    "promedio" : 8.7
}

estudiante3 = {
    "nombre" : "Pepita Romero",
    "edad" : 45,    
    "correo" : "Pepita@gmail.com",
    "activo" : True,
    "promedio" : 8.7
}

# print(estudiante["nombre"])
# print(nombre)
# print(f"cualquier cosas:{estudiante['nombre']}")
# print(f"Edad:{estudiante['edad']}")
# print(f"E-mail:{estudiante['correo']}")
# print(f"Activo:{estudiante['activo']}")
# print(f"Promedio:{estudiante['promedio']}")

#Actualizo un valor del diccionario
# estudiante["activo"]= False
# print(estudiante)

#Ahora agregadndo varios estudiantes


alumnos= [
    estudiante1,
    estudiante2,
    estudiante3
]


alumnos = [    
    estudiante1,
{
   "nombre" : "Javier Romero",
    "edad" : 45,    
    "correo" : "javier@gmail.com",
    "activo" : True,
    "promedio" : 8.7
},
    estudiante2,
{
    "nombre" : "Pepito Romero",
    "edad" : 45,    
    "correo" : "Pepito@gmail.com",
    "activo" : True,
    "promedio" : 8.7
},
    estudiante3,
{
    "nombre" :"Ppita Romero",
    "edad" : 45,    
    "correo" : "pepita@gmail.com",
    "activo" : True,
    "promedio" : 8.7
}
]


print("Estudiantes: ")
print(alumnos)
# Out:
# Estudiantes:
# [{'nombre': 'Javier Romero', 'edad': 45, 'correo': 'javier@gmail.com', 'activo': True, 'promedio': 8.7}, {'nombre': 'Javier Romero', 'edad': 45, 'correo': 'javier@gmail.com', 'activo': True, 'promedio': 8.7}, {'nombre': 'Pepito Romero', 'edad': 45, 'correo': 'pepito@gmail.com', 'activo': True, 'promedio': 8.7}, {'nombre': 'Pepito Romero', 'edad': 45, 'correo': 'Pepito@gmail.com', 'activo': True, 'promedio': 8.7}, {'nombre': 'Pepita Romero', 'edad': 45, 'correo': 'Pepita@gmail.com', 'activo': True, 'promedio': 8.7}, {'nombre': 'Ppita Romero', 'edad': 45, 'correo': 'pepita@gmail.com', 'activo': True, 'promedio': 8.7}]

# %% [markdown]
# # Condicionales y bucles
# > Condicionales  → if/el if/ else, es una estructura de control, controla el flujo del programa

# %%
nombre = "Ana"
promedio = 8.7
if promedio >= 7:
    print(f"Felicitaciones {nombre}")
elif promedio >=5:
    print(f"{nombre} Puedes mejorar")
else:
    print(f"Necesita mejorar")
# Out:
# Felicitaciones Ana

# %% [markdown]
# # Bucles
# > For es una estructura de iteració, recorre todo el elemento

# %%
learners = [ 
    {"nombre": "Pepita", "promedio": 8.7},
    {"nombre": "Pepito", "promedio": 7.5},
    {"nombre": "Andres", "promedio": 9.1}
]

for learner in learners:
 if learner["promedio"]>= 7:
    print(f"Felicitaciones {learner['nombre']}")
 elif learner["promedio"] >=5:
    print(f"{learner['nombre']} Puedes mejorar")
 else:
  print(f"Necesitas mejorar")
# Out:
# Felicitaciones Pepita
# Felicitaciones Pepito
# Felicitaciones Andres

# %%
## Funciones
