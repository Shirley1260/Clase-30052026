# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('spotify_colombia_2024.csv')
df.head()
# Out:
#          cancion          artista     genero        region  popularidad  \
# 0      Me Llamas     Carlos Vives  Vallenato  Barranquilla         88.0
# 1    Mi Libertad  Peter Manjarrés  Vallenato          Cali         63.0
# 2  Latinoamérica           Maluma  Reggaeton   Bucaramanga         81.0
# 3          Antes    Systema Solar   Afrobeat     Cartagena         47.0
# 4       Ojos Así    Jorge Celedón  Vallenato  Barranquilla         80.0
#
#    duracion_seg  streams_millones
# 0           255              4.42
# 1           183              3.58
# 2           194              3.84
# 3           210              3.16
# 4           205              2.73

# %%
print("Dimensiones:", df.shape)
print("Tipos de datos:df.dytpes")
print(" Tenemos nulos? ", df.isnull().sum())
# Out:
# Dimensiones: (600, 7)
# Tipos de datos:df.dytpes
#  Tenemos nulos?  cancion              0
# artista              0
# genero               0
# region               0
# popularidad          8
# duracion_seg         0
# streams_millones    10
# dtype: int64

# %%
plt.figure(figsize=(10, 5))

sns.histplot(data=df, x="popularidad", bins=60, kde=True, color="#1D88B9")

plt.title("La mayoría de canciones tienen popularidad entre 60 y 85")
plt.xlabel("Popularidad (escala 0 a 100)")
plt.ylabel("Cantidad de canciones")
plt.tight_layout()
plt.show()

# %%
sns.histplot(data=df, x="popularidad", bins=20, kde=True)
# Out:
# <Axes: xlabel='popularidad', ylabel='Count'>

# %%
sns.histplot(data=df, x="popularidad", bins=20, cumulative=True)
# Out:
# <Axes: xlabel='popularidad', ylabel='Count'>

# %%
# Estilo limpio sin cuadrícula
sns.set_style("white")   # elimina las líneas de la cuadrícula
sns.set_context("talk")  # fuentes más formales

# Histograma con curva de densidad (kde) y sin cuadrícula
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x="popularidad", bins=20, kde=True, color="#2E86C1", edgecolor="white")
plt.title("Distribución de popularidad de canciones", fontsize=14, fontweight="bold")
plt.xlabel("Popularidad (escala 0 a 100)", fontsize=12)
plt.ylabel("Número de canciones", fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.savefig("histograma_ejecutivo_sin_cuadricula.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(11, 5))
sns.kdeplot(data=df, x="popularidad", hue="genero",
fill=True, alpha=0.4, common_norm=False)
plt.title("¿Todos los géneros compiten en el mismo rango de popularidad?")
plt.xlabel("Popularidad (0 a 100)")
plt.ylabel("Densidad")
plt.tight_layout()
plt.show()

# %%
# Estilo corporativo limpio
sns.set_style("white")
sns.set_context("talk")

# Boxplot de popularidad
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x="popularidad", color="#2E86C1")
plt.title("Diagrama de caja y bigotes de popularidad", fontsize=14, fontweight="bold")
plt.xlabel("Popularidad (escala 0 a 100)", fontsize=12)
plt.xticks(fontsize=10)
plt.tight_layout()
plt.savefig("boxplot_popularidad.png", dpi=300, bbox_inches="tight")
plt.show()

# Boxplot por categorías (ejemplo: género musical)
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x="genero", y="popularidad", palette="Set2")
plt.title("Distribución de popularidad por género musical", fontsize=14, fontweight="bold")
plt.xlabel("Género musical", fontsize=12)
plt.ylabel("Popularidad (escala 0 a 100)", fontsize=12)
plt.xticks(rotation=45, fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.savefig("boxplot_genero.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_8984\2423978878.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="genero", y="popularidad", palette="Set2")

# %%
orden_generos = (df.groupby("genero")["popularidad"]

.median()

.sort_values(ascending=False)

.index)

plt.figure(figsize=(12, 6))

sns.boxplot(data=df, x="genero", y="popularidad",

order=orden_generos, palette="viridis")

plt.title("El reggaeton lidera en mediana — el jazz muestra mayor variabilidad")

plt.xlabel("Género musical")

plt.ylabel("Popularidad (0 a 100)")

plt.xticks(rotation=15)

plt.tight_layout()

plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_8984\3950596543.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="genero", y="popularidad",

# %%
plt.figure(figsize=(10, 5))

sns.countplot(data=df, x="region",

order=df["region"].value_counts().index,

palette="mako")

plt.title("¿Tenemos suficiente data de cada región para comparar?")

plt.xlabel("Región")

plt.ylabel("Cantidad de registros")

plt.xticks(rotation=15)

plt.tight_layout()

plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_8984\1122388378.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="region",

# %%
plt.figure(figsize=(11, 6))

sns.scatterplot(data=df, x="popularidad", y="streams_millones",

hue="genero", alpha=0.7, palette="tab10")

plt.title("Popularidad y streams se relacionan — pero los outliers cuentan otra historia")

plt.xlabel("Popularidad (0 a 100)")

plt.ylabel("Streams (millones)")

plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left", title="Género")

plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.regplot(data=df, x="popularidad", y="streams_millones",

scatter_kws={"alpha": 0.4, "color": "#1DB954"},

line_kws={"color": "red", "linewidth": 2})

plt.title("A mayor popularidad, más streams — la tendencia es clara aunque no perfecta")

plt.xlabel("Popularidad (0 a 100)")

plt.ylabel("Streams (millones)")

plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(14, 7))

sns.barplot(data=df, x="region", y="popularidad",

hue="genero", estimator="mean",

palette="Set2", errorbar=None)

plt.title("Cada región tiene su género dominante — la inversión debe ser segmentada")

plt.xlabel("Región")

plt.ylabel("Popularidad promedio")

plt.xticks(rotation=15)

plt.legend(title="Género", bbox_to_anchor=(1.05, 1), loc="upper left")

plt.tight_layout()

plt.show()

# %%
numericas = df[["popularidad", "duracion_seg", "streams_millones"]]

matriz_correlacion = numericas.corr()

plt.figure(figsize=(8, 6))

sns.heatmap(matriz_correlacion, annot=True, fmt=".2f",

            cmap="coolwarm", vmin=-1, vmax=1,

            center=0, linewidths=0.5)

plt.title("Popularidad y streams se relacionan — la duración no define el éxito")

plt.tight_layout()
